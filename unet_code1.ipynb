# %% [markdown]
# <a href="https://colab.research.google.com/github/suryam3107/MAJOR_PROJECT/blob/main/unet_code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/reachsumit/deep-unet-for-satellite-image-segmentation.git
# Out:
# Cloning into 'deep-unet-for-satellite-image-segmentation'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 92 (delta 12), reused 10 (delta 10), pack-reused 71
# Unpacking objects: 100% (92/92), 144.86 MiB | 11.04 MiB/s, done.
# Updating files: 100% (61/61), done.

# %%
# !git clone https://github.com/tensorflow/tensorflow.git
# Out:
# Cloning into 'tensorflow'...
# remote: Enumerating objects: 1540350, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 1540350 (delta 42), reused 108 (delta 33), pack-reused 1540228
# Receiving objects: 100% (1540350/1540350), 966.56 MiB | 28.86 MiB/s, done.
# Resolving deltas: 100% (1248605/1248605), done.
# Updating files: 100% (29236/29236), done.

# %%
# !python3 /content/deep-unet-for-satellite-image-segmentation/train_unet.py
# Out:
# 2023-03-12 19:57:14.964379: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-12 19:57:17.566686: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-12 19:57:17.566803: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...

# %%
# !python3 /content/deep-unet-for-satellite-image-segmentation/predict.py
# Out:
# 2023-03-12 20:33:18.501649: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-12 20:33:19.370881: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-12 20:33:19.370985: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# ...
